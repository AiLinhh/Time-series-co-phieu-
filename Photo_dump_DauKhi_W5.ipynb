# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import statsmodels.api as sm
import statsmodels.formula.api as smf
import os
# %matplotlib inline

# %%
path = 'Downloads/XuLyDaukhixyz.xlsx'
df = pd.read_excel(path)
df
# Out:
#            Date   PCG   PLX        PVB        PVC        PVO
# 0    2017-01-03   8.6   NaN  10.900000   8.000000   3.500000
# 1    2017-01-04   8.6   NaN  10.900000   8.100000   3.500000
# 2    2017-01-05   8.6   NaN  10.500000   8.100000   3.600000
# 3    2017-01-06   8.6   NaN  10.300000   8.000000   3.600000
# 4    2017-01-07   8.6   NaN  10.333333   8.033333   3.633333
# ...         ...   ...   ...        ...        ...        ...
# 1819 2021-12-27   9.6  54.1  19.000000  16.400000  10.100000
# 1820 2021-12-28   9.8  53.8  19.300000  16.600000   9.900000
# 1821 2021-12-29  10.7  54.0  19.500000  16.600000   9.900000
# 1822 2021-12-30  10.7  54.0  20.600000  17.200000  10.000000
# 1823 2021-12-31  10.5  53.9  19.700000  16.800000   9.900000
#
# [1824 rows x 6 columns]

# %%
sns.lineplot('Date', 'PCG', data=df)
# Out:
# C:\Users\nhom\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='PCG'>

# %%
sns.lineplot('Date', 'PLX', data=df)
# Out:
# C:\Users\nhom\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='PLX'>

# %%
sns.lineplot('Date', 'PVB', data=df)
# Out:
# C:\Users\nhom\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='PVB'>

# %%
sns.lineplot('Date', 'PVC', data=df)
# Out:
# C:\Users\nhom\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='PVC'>

# %%
sns.lineplot('Date', 'PVO', data=df)
# Out:
# C:\Users\nhom\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='PVO'>

# %%
#PCG	PLX	PVB	PVC	PVO
plt.scatter('Date', 'PCG', data=df)

# %%
plt.scatter('Date', 'PLX', data=df)

# %%
plt.scatter('Date', 'PVB', data=df)

# %%
plt.scatter('Date', 'PVC', data=df)

# %%
plt.scatter('Date', 'PVO', data=df)

# %%
#PCG	PLX	PVB	PVC	PVO
plt.scatter('Date', 'PCG', data=df)
plt.scatter('Date', 'PLX', data=df)
plt.scatter('Date', 'PVO', data=df)
plt.scatter('Date', 'PVC', data=df)
plt.scatter('Date', 'PVB', data=df)

# %%
df.hist()
plt.show()

# %%
df1 =df[["PCG","PLX","PVB","PVC","PVO"]]
df1
# Out:
#        PCG   PLX        PVB        PVC        PVO
# 0      8.6   NaN  10.900000   8.000000   3.500000
# 1      8.6   NaN  10.900000   8.100000   3.500000
# 2      8.6   NaN  10.500000   8.100000   3.600000
# 3      8.6   NaN  10.300000   8.000000   3.600000
# 4      8.6   NaN  10.333333   8.033333   3.633333
# ...    ...   ...        ...        ...        ...
# 1819   9.6  54.1  19.000000  16.400000  10.100000
# 1820   9.8  53.8  19.300000  16.600000   9.900000
# 1821  10.7  54.0  19.500000  16.600000   9.900000
# 1822  10.7  54.0  20.600000  17.200000  10.000000
# 1823  10.5  53.9  19.700000  16.800000   9.900000
#
# [1824 rows x 5 columns]

# %%
df1.plot(kind='density',subplots=True,layout=(3,3),sharex=False)
plt.show()

# %%
df1.plot.box(grid='True')
# Out:
# <AxesSubplot:>

# %%
g = sns.clustermap(df.corr(), 
                   method = 'complete', 
                   cmap   = 'RdBu', 
                   annot  = True, 
                   annot_kws = {'size': 8})
plt.setp(g.ax_heatmap.get_xticklabels(), rotation=60);

# %%
#PVC PVO PLX PCG PVB
df2 = df["PVC"]
df3 = df["PVO"]
df4 = df["PLX"]
df5 = df["PCG"]
df6 = df["PVB"]

# %%
#PVC
pd.plotting.lag_plot(df2, lag=3)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 3)'>

# %%
#PVO
pd.plotting.lag_plot(df3, lag=3)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 3)'>

# %%
#PLX
pd.plotting.lag_plot(df4, lag=3)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 3)'>

# %%
#PCG
pd.plotting.lag_plot(df5, lag=3)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 3)'>

# %%
#PVB
pd.plotting.lag_plot(df6, lag=3)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 3)'>

# %%
#PVC 
# Creating Autocorrelation plot
x = pd.plotting.autocorrelation_plot(df2)
 
# plotting the Curve
x.plot()
 
# Display
plt.show()

# %%
#PVO 
# Creating Autocorrelation plot
x = pd.plotting.autocorrelation_plot(df3)
 
# plotting the Curve
x.plot()
 
# Display
plt.show()

# %%
df.set_index('Date', inplace=True)
df0 = df[df.index > pd.to_datetime("2017-4-20", format='%Y-%m-%d')]
df0
# Out:
#              PCG        PLX        PVB   PVC   PVO
# Date
# 2017-04-21   8.5  48.900000   9.900000   7.5   5.1
# 2017-04-22   8.5  48.733333   9.933333   7.5   5.0
# 2017-04-23   8.5  48.566667   9.966667   7.5   4.9
# 2017-04-24   8.5  48.400000  10.000000   7.5   4.8
# 2017-04-25   8.5  45.150000  10.000000   7.6   4.9
# ...          ...        ...        ...   ...   ...
# 2021-12-27   9.6  54.100000  19.000000  16.4  10.1
# 2021-12-28   9.8  53.800000  19.300000  16.6   9.9
# 2021-12-29  10.7  54.000000  19.500000  16.6   9.9
# 2021-12-30  10.7  54.000000  20.600000  17.2  10.0
# 2021-12-31  10.5  53.900000  19.700000  16.8   9.9
#
# [1716 rows x 5 columns]

# %%
#PLX
# Creating Autocorrelation plot
df_1 = df0["PLX"]
x = pd.plotting.autocorrelation_plot(df_1)
 
# plotting the Curve
x.plot()
 
# Display
plt.show()

# %%
#PCG
# Creating Autocorrelation plot
x = pd.plotting.autocorrelation_plot(df5)
 
# plotting the Curve
x.plot()
 
# Display
plt.show()

# %%
#PVB
# Creating Autocorrelation plot
x = pd.plotting.autocorrelation_plot(df6)
 
# plotting the Curve
x.plot()
 
# Display
plt.show()

# %%
#1. Phân tích level:

path = 'Downloads/XuLyDaukhixyz.xlsx'
df = pd.read_excel(path)
df
#Tính trung bình động (moving average) của biến PCG trong 7 ngày
df['PCG_MA7'] = df['PCG'].rolling(window=7).mean()
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(df['Date'], df['PCG'])
ax.plot(df['Date'], df['PCG_MA7'])
ax.legend(['PCG', 'PCG_MA7'])
ax.set_title('Moving Average PCG')
plt.show()

#2. Phân tích trend:

from sklearn.linear_model import LinearRegression

X = df.index.values.reshape(-1, 1)
y = df['PCG']
model = LinearRegression().fit(X, y)
trend = model.predict(X)
df['PCG_trend'] = trend

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(df['Date'], df['PCG'])
ax.plot(df['Date'], df['PCG_trend'])
ax.legend(['PCG', 'PCG_trend'])
ax.set_title('Trend')
plt.show()

from statsmodels.tsa.seasonal import seasonal_decompose
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

result = seasonal_decompose(df['PCG'], model='multiplicative', period=30)
df['PCG_trend'] = result.trend
df['PCG_seasonality'] = result.seasonal
df['PCG_residual'] = result.resid
fig, ax = plt.subplots(nrows=4, ncols=1, figsize=(10, 12), sharex=True)
ax[0].plot(df['PCG'])
ax[0].set_ylabel('PCG')
ax[1].plot(df['PCG_trend'])
ax[1].set_ylabel('Trend')
ax[2].plot(df['PCG_seasonality'])
ax[2].set_ylabel('Seasonality')
ax[3].plot(df['PCG_residual'])
ax[3].set_ylabel('Residual')
plt.show()

# %%
#PCG	PLX	PVB	PVC	PVO
path = 'Downloads/XuLyDaukhixyz.xlsx'
df = pd.read_excel(path)
df

#1. Phân tích level:
#Tính trung bình động (moving average) của biến PCG trong 7 ngày
df['PVB_MA7'] = df['PVB'].rolling(window=7).mean()
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(df['Date'], df['PVB'])
ax.plot(df['Date'], df['PVB_MA7'])
ax.legend(['PVB', 'PVB_MA7'])
ax.set_title('Moving Average PVB')
plt.show()

#2. Phân tích trend:

from sklearn.linear_model import LinearRegression

X = df.index.values.reshape(-1, 1)
y = df['PVB']
model = LinearRegression().fit(X, y)
trend = model.predict(X)
df['PVB_trend'] = trend

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(df['Date'], df['PVB'])
ax.plot(df['Date'], df['PVB_trend'])
ax.legend(['PVB', 'PVB_trend'])
ax.set_title('Trend')
plt.show()


from statsmodels.tsa.seasonal import seasonal_decompose
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

result = seasonal_decompose(df['PVB'], model='multiplicative', period=30)
df['PVB_trend'] = result.trend
df['PVB_seasonality'] = result.seasonal
df['PVB_residual'] = result.resid
fig, ax = plt.subplots(nrows=4, ncols=1, figsize=(10, 12), sharex=True)
ax[0].plot(df['PVB'])
ax[0].set_ylabel('PVB')
ax[1].plot(df['PVB_trend'])
ax[1].set_ylabel('Trend')
ax[2].plot(df['PVB_seasonality'])
ax[2].set_ylabel('Seasonality')
ax[3].plot(df['PVB_residual'])
ax[3].set_ylabel('Residual')
plt.show()

# %%
#2. Phân tích trend:

from sklearn.linear_model import LinearRegression

X = df.index.values.reshape(-1, 1)
y = df['PVB']
model = LinearRegression().fit(X, y)
trend = model.predict(X)
df['PVB_trend'] = trend

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(df['Date'], df['PVB'])
ax.plot(df['Date'], df['PVB_trend'])
ax.legend(['PVB', 'PVB_trend'])
ax.set_title('Trend')
plt.show()


from statsmodels.tsa.seasonal import seasonal_decompose
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

result = seasonal_decompose(df['PVB'], model='multiplicative', period=30)
df['PVB_trend'] = result.trend
df['PVB_seasonality'] = result.seasonal
df['PVB_residual'] = result.resid
fig, ax = plt.subplots(nrows=4, ncols=1, figsize=(10, 12), sharex=True)
ax[0].plot(df['PVB'])
ax[0].set_ylabel('PVB')
ax[1].plot(df['PVB_trend'])
ax[1].set_ylabel('Trend')
ax[2].plot(df['PVB_seasonality'])
ax[2].set_ylabel('Seasonality')
ax[3].plot(df['PVB_residual'])
ax[3].set_ylabel('Residual')
plt.show()

# %%
#PCG	PLX	PVB	PVC	PVO

path = 'Downloads/XuLyDaukhixyz.xlsx'
df = pd.read_excel(path)
df
#1. Phân tích level:
#Tính trung bình động (moving average) của biến PCG trong 7 ngày
df['PLX_MA7'] = df['PLX'].rolling(window=7).mean()
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(df['Date'], df['PLX'])
ax.plot(df['Date'], df['PLX_MA7'])
ax.legend(['PLX', 'PLX_MA7'])
ax.set_title('Moving Average PLX')
plt.show()

# %%
#2. Phân tích trend:

from statsmodels.tsa.seasonal import seasonal_decompose
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

df0 = df[df.index > pd.to_datetime("2017-4-20", format='%Y-%m-%d')]
df0
# Out:
#              PCG        PLX        PVB   PVC   PVO    PLX_MA7
# Date
# 2017-04-21   8.5  48.900000   9.900000   7.5   5.1        NaN
# 2017-04-22   8.5  48.733333   9.933333   7.5   5.0        NaN
# 2017-04-23   8.5  48.566667   9.966667   7.5   4.9        NaN
# 2017-04-24   8.5  48.400000  10.000000   7.5   4.8        NaN
# 2017-04-25   8.5  45.150000  10.000000   7.6   4.9        NaN
# ...          ...        ...        ...   ...   ...        ...
# 2021-12-27   9.6  54.100000  19.000000  16.4  10.1  53.257143
# 2021-12-28   9.8  53.800000  19.300000  16.6   9.9  53.371429
# 2021-12-29  10.7  54.000000  19.500000  16.6   9.9  53.542857
# 2021-12-30  10.7  54.000000  20.600000  17.2  10.0  53.714286
# 2021-12-31  10.5  53.900000  19.700000  16.8   9.9  53.842857
#
# [1716 rows x 6 columns]

# %%
X = df0.index.values.reshape(-1, 1)
y = df0['PLX']
model = LinearRegression().fit(X, y)
trend = model.predict(X)
df0['PLX_trend'] = trend

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(df0['Date'], df0['PLX'])
ax.plot(df0['Date'], df0['PLX_trend'])
ax.legend(['PLX', 'PLX_trend'])
ax.set_title('Trend')
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose


result = seasonal_decompose(df0['PLX'], model='multiplicative', period=30)
df0['PLX_trend'] = result.trend
df0['PLX_seasonality'] = result.seasonal
df0['PLX_residual'] = result.resid
fig, ax = plt.subplots(nrows=4, ncols=1, figsize=(10, 12), sharex=True)
ax[0].plot(df0['PLX'])
ax[0].set_ylabel('PLX')
ax[1].plot(df0['PLX_trend'])
ax[1].set_ylabel('Trend')
ax[2].plot(df0['PLX_seasonality'])
ax[2].set_ylabel('Seasonality')
ax[3].plot(df0['PLX_residual'])
ax[3].set_ylabel('Residual')
plt.show()

# %%
#PCG	PLX	PVB	PVC	PVO
path = 'Downloads/XuLyDaukhixyz.xlsx'
df = pd.read_excel(path)
df

#1. Phân tích level:
#Tính trung bình động (moving average) của biến PCG trong 7 ngày
df['PVC_MA7'] = df['PVC'].rolling(window=7).mean()
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(df['Date'], df['PVC'])
ax.plot(df['Date'], df['PVC_MA7'])
ax.legend(['PVC', 'PVC_MA7'])
ax.set_title('Moving Average PVC')
plt.show()

#2. Phân tích trend:

from sklearn.linear_model import LinearRegression

X = df.index.values.reshape(-1, 1)
y = df['PVC']
model = LinearRegression().fit(X, y)
trend = model.predict(X)
df['PVC_trend'] = trend

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(df['Date'], df['PVC'])
ax.plot(df['Date'], df['PVC_trend'])
ax.legend(['PVC', 'PVC_trend'])
ax.set_title('Trend')
plt.show()


from statsmodels.tsa.seasonal import seasonal_decompose
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

result = seasonal_decompose(df['PVC'], model='multiplicative', period=30)
df['PVC_trend'] = result.trend
df['PVC_seasonality'] = result.seasonal
df['PVC_residual'] = result.resid
fig, ax = plt.subplots(nrows=4, ncols=1, figsize=(10, 12), sharex=True)
ax[0].plot(df['PVC'])
ax[0].set_ylabel('PVC')
ax[1].plot(df['PVC_trend'])
ax[1].set_ylabel('Trend')
ax[2].plot(df['PVC_seasonality'])
ax[2].set_ylabel('Seasonality')
ax[3].plot(df['PVC_residual'])
ax[3].set_ylabel('Residual')
plt.show()

# %%
#PCG	PLX	PVB	PVC	PVO
path = 'Downloads/XuLyDaukhixyz.xlsx'
df = pd.read_excel(path)
df

#1. Phân tích level:
#Tính trung bình động (moving average) của biến PCG trong 7 ngày
df['PVO_MA7'] = df['PVO'].rolling(window=7).mean()
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(df['Date'], df['PVO'])
ax.plot(df['Date'], df['PVO_MA7'])
ax.legend(['PVO', 'PVO_MA7'])
ax.set_title('Moving Average PVO')
plt.show()

#2. Phân tích trend:

from sklearn.linear_model import LinearRegression

X = df.index.values.reshape(-1, 1)
y = df['PVO']
model = LinearRegression().fit(X, y)
trend = model.predict(X)
df['PVO_trend'] = trend

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(df['Date'], df['PVO'])
ax.plot(df['Date'], df['PVO_trend'])
ax.legend(['PVO', 'PVO_trend'])
ax.set_title('Trend')
plt.show()


from statsmodels.tsa.seasonal import seasonal_decompose
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

result = seasonal_decompose(df['PVO'], model='multiplicative', period=30)
df['PVO_trend'] = result.trend
df['PVO_seasonality'] = result.seasonal
df['PVO_residual'] = result.resid
fig, ax = plt.subplots(nrows=4, ncols=1, figsize=(10, 12), sharex=True)
ax[0].plot(df['PVO'])
ax[0].set_ylabel('PVO')
ax[1].plot(df['PVO_trend'])
ax[1].set_ylabel('Trend')
ax[2].plot(df['PVO_seasonality'])
ax[2].set_ylabel('Seasonality')
ax[3].plot(df['PVO_residual'])
ax[3].set_ylabel('Residual')
plt.show()

# %%
#PCG	PLX	PVB	PVC	PVO
path = 'Downloads/XuLyDaukhixyzz.xlsx'
df = pd.read_excel(path)


df['Date'] = pd.to_datetime(df['Date'])
# calculate the monthly percentage change
df['Pct_Change'] = df.groupby(['Year','Month'])['PCG'].pct_change()

# fill missing values with the mean of that month
df['Pct_Change'] = df.groupby(['Month'])['Pct_Change'].fillna(df['Pct_Change'].mean())

# create the pivot table with columns as months and rows as years
pivot = df.pivot_table(index='Year', columns='Month', values='Pct_Change', aggfunc='sum')

# plot the heatmap with green for positive changes and red for negative changes
import seaborn as sns
import matplotlib.pyplot as plt

cmap = sns.diverging_palette(10, 220, as_cmap=True)



fig = plt.figure(figsize=(17, 7))
sns.heatmap(pivot, cmap=cmap, center=0, annot=True, fmt=".2%")
plt.title("Percentage Change in PCG by Month and Year")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

path = 'Downloads/XuLyDaukhixyzz.xlsx'
df = pd.read_excel(path)
# Tạo pivot table
df_pivot = pd.pivot_table(df, values='PCG', index=['Month'], columns=['Year'])

# Tính moving average
df_pivot_ma = df_pivot.rolling(window=3).mean()

# Vẽ biểu đồ line chart kết hợp cả dữ liệu gốc và dữ liệu đã tính moving average
sns.set_style("whitegrid")
sns.set_palette("husl")
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_pivot_ma, color="lightgray")
plt.title("PCG by Year")
plt.xlabel("Month")
plt.ylabel("PCG")
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %%
path = 'Downloads/XuLyDaukhixyzz.xlsx'
df = pd.read_excel(path)
# Tạo pivot table
df_pivot = pd.pivot_table(df, values='PVC', index=['Month'], columns=['Year'])

# Tính moving average
df_pivot_ma = df_pivot.rolling(window=3).mean()

# Vẽ biểu đồ line chart kết hợp cả dữ liệu gốc và dữ liệu đã tính moving average
sns.set_style("whitegrid")
sns.set_palette("husl")
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_pivot_ma, color="lightgray")
plt.title("PVC by Year")
plt.xlabel("Month")
plt.ylabel("PVC")
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %%
path = 'Downloads/XuLyDaukhixyzz.xlsx'
df = pd.read_excel(path)
# Tạo pivot table
df_pivot = pd.pivot_table(df, values='PVO', index=['Month'], columns=['Year'])

# Tính moving average
df_pivot_ma = df_pivot.rolling(window=3).mean()

# Vẽ biểu đồ line chart kết hợp cả dữ liệu gốc và dữ liệu đã tính moving average
sns.set_style("whitegrid")
sns.set_palette("husl")
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_pivot_ma, color="lightgray")
plt.title("PVO by Year")
plt.xlabel("Month")
plt.ylabel("PVO")
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %%
path = 'Downloads/XuLyDaukhixyzz.xlsx'
df = pd.read_excel(path)
# Tạo pivot table
df_pivot = pd.pivot_table(df, values='PVB', index=['Month'], columns=['Year'])

# Tính moving average
df_pivot_ma = df_pivot.rolling(window=3).mean()

# Vẽ biểu đồ line chart kết hợp cả dữ liệu gốc và dữ liệu đã tính moving average
sns.set_style("whitegrid")
sns.set_palette("husl")
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_pivot_ma, color="lightgray")
plt.title("PVB by Year")
plt.xlabel("Month")
plt.ylabel("PVB")
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %%
path = 'Downloads/XuLyDaukhixyzz.xlsx'
df = pd.read_excel(path)
# Tạo pivot table
df_pivot = pd.pivot_table(df, values='PLX', index=['Month'], columns=['Year'])

# Tính moving average
df_pivot_ma = df_pivot.rolling(window=3).mean()

# Vẽ biểu đồ line chart kết hợp cả dữ liệu gốc và dữ liệu đã tính moving average
sns.set_style("whitegrid")
sns.set_palette("husl")
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_pivot_ma, color="lightgray")
plt.title("PLX by Year")
plt.xlabel("Month")
plt.ylabel("PLX")
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()
